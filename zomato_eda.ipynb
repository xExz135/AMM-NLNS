# %%
import pickle

with open(r"d:\AMM_Arc1\NLNS\instances\zomato.pkl", "rb") as f:
    data = pickle.load(f)

print("instances:", len(data))
depot, loc, demand, capacity = data[0]
print("depot:", depot)
print("customers:", len(loc))
print("first 5 locations:", loc[:5])
print("first 5 demands:", demand[:5])
print("capacity:", capacity)
# Out:
# instances: 704
# depot: [0.9882812546022919, 0.9405563461490454]
# customers: 35
# first 5 locations: [[0.9894110226855978, 0.9409519835816796], [0.9897338135665423, 0.9410650228481465], [0.9890882318046532, 0.9408389443152129], [0.990056604447487, 0.9411780621146135], [0.9905407907689039, 0.9413476210143139]]
# first 5 demands: [3, 1, 1, 1, 1]
# capacity: 10

# %%
import pickle

with open(r"C:\Users\shana\Documents\School\AMM-NLNS\instances\zomato_chunked.pkl", "rb") as f:
    data = pickle.load(f)

print("instances:", len(data))
depot, loc, demand, capacity = data[0]
print("depot:", depot)
print("customers:", len(loc))
print("first 5 locations:", loc[:5])
print("first 5 demands:", demand[:5])
print("capacity:", capacity)
# Out:
# instances: 1425
# depot: [0.9894211099006274, 0.9409555160587567]
# customers: 32
# first 5 locations: [[0.9894110226855978, 0.9409519835816796], [0.9897338135665423, 0.9410650228481465], [0.9890882318046532, 0.9408389443152129], [0.990056604447487, 0.9411780621146135], [0.9905407907689039, 0.9413476210143139]]
# first 5 demands: [3, 1, 1, 1, 1]
# capacity: 10
